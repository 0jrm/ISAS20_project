# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pickle
import os
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import sys

# Add the parent directory to the Python path
# sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
sys.path.append('/unity/g2/jmiranda/SubsurfaceFields/Data/ISAS20_ARGO/ISAS20_project/NeSPReSO2_onTemplate')
from model.model import Autoencoder, KAN_Autoencoder

class MaskedMSELoss(nn.Module):
    def __init__(self):
        super(MaskedMSELoss, self).__init__()
        
    def forward(self, pred, target, mask):
        """
        Compute MSE loss only on unmasked values
        
        Args:
            pred: predicted values
            target: target values
            mask: boolean mask (True for NaN/masked values, False for valid values)
        """
        # Convert mask to float and invert it (1 for valid, 0 for masked)
        valid_mask = (~mask).float()
        
        # # Print debugging information for first batch
        # if pred.shape[0] > 0:
        #     print("\nLoss debugging information:")
        #     print(f"Prediction range: [{pred[0].min():.3f}, {pred[0].max():.3f}]")
        #     print(f"Target range: [{target[0].min():.3f}, {target[0].max():.3f}]")
        #     print(f"Number of valid points: {torch.sum(valid_mask[0])}")
        #     print(f"Number of masked points: {torch.sum(mask[0])}")
        #     print(f"Valid locations: {torch.where(valid_mask[0])[0]}")
        #     print(f"Masked locations: {torch.where(mask[0])[0]}")
        
        # Compute squared error
        squared_error = (pred - target) ** 2
        
        # Apply mask and compute mean only over valid values
        masked_error = squared_error * valid_mask
        sum_error = torch.sum(masked_error)
        num_valid = torch.sum(valid_mask)
        
        # Avoid division by zero
        if num_valid == 0:
            return torch.tensor(0.0, device=pred.device)
        
        # # Print loss components
        # print(f"Sum error: {sum_error:.3f}")
        # print(f"Number of valid points: {num_valid}")
        # print(f"Final loss: {sum_error / num_valid:.3f}")
            
        return sum_error / num_valid

def load_data(data_path, parameter_name):
    """Load and prepare the preprocessed data for a specific parameter
    
    Args:
        data_path (str): Path to the preprocessed data file
        parameter_name (str): Name of the parameter to load (e.g., 'temperature_TEMP' or 'salinity_PSAL')
    """
    with open(data_path, 'rb') as f:
        data = pickle.load(f)
    
    # Get parameter data and mask
    param_data = data['outputs'][parameter_name]
    mask = data['masks'][parameter_name]
    
    # # Print debugging information
    # print("\nData loading debugging information:")
    # print(f"Salinity shape: {param_data.shape}")
    # print(f"Mask shape: {mask.shape}")
    # print(f"Number of masked points in first profile: {torch.sum(~mask[0])}")
    # print(f"Masked locations in first profile: {torch.where(~mask[0])[0]}")
    
    # Convert to float32 for better performance
    param_data = param_data.float()
    mask = mask.bool()
    
    return param_data, mask

def train_autoencoder(model, train_loader, val_loader, num_epochs, device, model_name):
    """Train the autoencoder"""
    criterion = MaskedMSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5)
    
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    
    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0
        for batch_x, batch_mask in tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs}'):
            batch_x = batch_x.to(device)
            batch_mask = batch_mask.to(device)
            
            optimizer.zero_grad()
            outputs = model(batch_x, batch_mask)
            
            # # Print input and output ranges for debugging
            # if epoch == 0 and train_loss == 0:
            #     print("\nTraining debugging information:")
            #     print(f"Input range: [{batch_x[0].min():.3f}, {batch_x[0].max():.3f}]")
            #     print(f"Output range: [{outputs[0].min():.3f}, {outputs[0].max():.3f}]")
            #     print(f"Number of valid points: {torch.sum(~batch_mask[0])}")
            #     print(f"Number of masked points: {torch.sum(batch_mask[0])}")
            
            loss = criterion(outputs, batch_x, batch_mask)
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_x, batch_mask in val_loader:
                batch_x = batch_x.to(device)
                batch_mask = batch_mask.to(device)
                
                outputs = model(batch_x, batch_mask)
                loss = criterion(outputs, batch_x, batch_mask)
                val_loss += loss.item()
        
        val_loss /= len(val_loader)
        val_losses.append(val_loss)
        
        # Learning rate scheduling
        scheduler.step(val_loss)
        
        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), f'best_{model_name}.pth')
        
        # if (epoch + 1) % 10 == 0:
            # print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Training Loss: {train_loss:.2e} | Validation Loss: {val_loss:.2e}')
    
    return train_losses, val_losses

def plot_losses(train_losses, val_losses, model_name):
    """Plot training and validation losses"""
    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'{model_name} Training and Validation Losses')
    plt.legend()
    # plt.savefig(f'{model_name}_losses.png')
    plt.show()
    # plt.close()

def plot_profiles(original, reconstructed, mask, model_name, num_profiles=4):
    """Plot original vs reconstructed profiles for a few examples
    
    Args:
        original: Original data tensor
        reconstructed: Reconstructed data tensor
        mask: Boolean mask (True for masked values)
        model_name: Name of the model for the plot title
        num_profiles: Number of profiles to plot (default: 4)
    """
    # Convert tensors to numpy arrays
    original = original.cpu().numpy()
    reconstructed = reconstructed.cpu().numpy()
    mask = mask.cpu().numpy()
    
    # Create figure with subplots
    fig, axes = plt.subplots(num_profiles, 1, figsize=(8, 4*num_profiles))
    
    # Plot each profile
    for i in range(num_profiles):
        ax = axes[i]
        # Plot original profile
        ax.plot(original[i], range(len(original[i])), 'b-', label='Original', alpha=0.7)
        # Plot reconstructed profile
        ax.plot(reconstructed[i], range(len(reconstructed[i])), 'r--', label='Reconstructed', alpha=0.7)
        # Plot masked points (where mask is True, i.e., NaN values)
        masked_points = np.where(mask[i])[0]
        if len(masked_points) > 0:
            ax.scatter(original[i][masked_points], masked_points, 
                      color='gray', alpha=0.3, label='Masked')
        
        ax.set_title(f'Profile {i+1}')
        ax.set_xlabel('Value')
        ax.set_ylabel('Depth Level')
        ax.invert_yaxis()  # Invert y-axis to show depth increasing downward
    
    # Add legend to the first subplot
    axes[0].legend()
    plt.suptitle(f'{model_name} - Original vs Reconstructed Profiles')
    plt.tight_layout()
    
    # plt.savefig(f'{model_name}_profiles.png')
    plt.show()
    # plt.close()

def calculate_captured_variance(original, reconstructed, mask):
    """
    Calculate the variance captured by the reconstruction, ignoring masked values.
    
    Args:
        original: Original data tensor
        reconstructed: Reconstructed data tensor
        mask: Boolean mask (True for masked values)
    
    Returns:
        float: Percentage of variance captured
    """
    # Convert mask to float and invert it (1 for valid, 0 for masked)
    valid_mask = (~mask).float()
    
    # Calculate total variance of original data (only on valid points)
    original_mean = (original * valid_mask).sum() / valid_mask.sum()
    total_variance = ((original - original_mean) ** 2 * valid_mask).sum() / valid_mask.sum()
    
    # Calculate reconstruction error variance
    error_variance = ((original - reconstructed) ** 2 * valid_mask).sum() / valid_mask.sum()
    
    # Calculate captured variance percentage
    captured_variance = (1 - error_variance / total_variance) * 100
    
    return captured_variance

def plot_combined_profiles(original, reconstructions, mask, parameter_name, encoding_dims, num_profiles=4):
    """Plot original vs reconstructed profiles for all encoding dimensions in a grid
    
    Args:
        original: Original data tensor
        reconstructions: List of reconstructed data tensors for each encoding dimension
        mask: Boolean mask (True for masked values)
        parameter_name: Name of the parameter being plotted
        encoding_dims: List of encoding dimensions used
        num_profiles: Number of profiles to plot (default: 4)
    """
    # Convert tensors to numpy arrays
    original = original.cpu().numpy()
    reconstructions = [r.cpu().numpy() for r in reconstructions]
    mask = mask.cpu().numpy()
    
    # Create figure with subplots
    fig, axes = plt.subplots(num_profiles, len(encoding_dims), figsize=(4*len(encoding_dims), 4*num_profiles))
    
    # Plot each profile
    for i in range(num_profiles):
        # Plot reconstructions for each encoding dimension
        for j, (recon, dim) in enumerate(zip(reconstructions, encoding_dims)):
            ax = axes[i, j]
            ax.plot(original[i], range(len(original[i])), 'b-', label='Original', alpha=0.7)
            ax.plot(recon[i], range(len(recon[i])), 'r--', label='Reconstructed', alpha=0.7)
            masked_points = np.where(mask[i])[0]
            if len(masked_points) > 0:
                ax.scatter(original[i][masked_points], masked_points, 
                          color='gray', alpha=0.3, label='Masked')
            ax.set_title(f'Profile {i+1} - Dim {dim}')
            ax.set_xlabel('Value')
            if j == 0:  # Only show y-label for first column
                ax.set_ylabel('Depth Level')
            ax.invert_yaxis()
    
    # Add legend to the first subplot
    axes[0, 0].legend()
    plt.suptitle(f'{parameter_name} - Original vs Reconstructed Profiles for Different Encoding Dimensions')
    plt.tight_layout()
    plt.show()

def plot_combined_losses(train_losses_list, val_losses_list, parameter_name, encoding_dims):
    """Plot training and validation losses for all encoding dimensions
    
    Args:
        train_losses_list: List of training losses for each encoding dimension
        val_losses_list: List of validation losses for each encoding dimension
        parameter_name: Name of the parameter being plotted
        encoding_dims: List of encoding dimensions used
    """
    plt.figure(figsize=(10, 6))
    
    # Plot losses for each encoding dimension
    for i, (train_losses, val_losses, dim) in enumerate(zip(train_losses_list, val_losses_list, encoding_dims)):
        plt.semilogy(train_losses, label=f'Train (dim={dim})', alpha=0.7)
        plt.semilogy(val_losses, label=f'Val (dim={dim})', linestyle='--', alpha=0.7)
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss (log scale)')
    plt.title(f'{parameter_name} - Training and Validation Losses for Different Encoding Dimensions')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

def main():
    # Set device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f'Using device: {device}')
    
    # Set random seed for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)
    
    # Load data
    data_path = '/unity/g2/jmiranda/SubsurfaceFields/Data/ISAS20_ARGO/ISAS20_project/data/NeSPReSO_v2_GoM_sat/preprocessed_satellite_data.pkl'
    
    # Get available parameters from the data file
    with open(data_path, 'rb') as f:
        data = pickle.load(f)
    available_params = list(data['outputs'].keys())
    print(f"Available parameters: {available_params}")
    
    # List of parameters to process
    parameter_names = ['salinity_PSAL', 'temperature_TEMP']
    print(f"\nProcessing parameters: {parameter_names}")
    
    # Process each parameter
    for parameter_name in parameter_names:
        print(f"\n{'='*50}")
        print(f"Processing parameter: {parameter_name}")
        print(f"{'='*50}")
        
        param_data, mask = load_data(data_path, parameter_name)
        
        # Create random indices for train/val split
        num_samples = len(param_data)
        indices = torch.randperm(num_samples)
        train_size = int(0.8 * num_samples)
        train_indices = indices[:train_size]
        val_indices = indices[train_size:]
        
        # Create datasets using the random indices
        train_dataset = TensorDataset(param_data[train_indices], mask[train_indices])
        val_dataset = TensorDataset(param_data[val_indices], mask[val_indices])
        
        # Create dataloaders
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
        
        # Select random profiles for visualization (same across all encoding dimensions)
        num_vis_profiles = 4
        vis_indices = torch.randperm(len(val_dataset))[:num_vis_profiles]
        vis_data = torch.stack([val_dataset[i][0] for i in vis_indices])
        vis_mask = torch.stack([val_dataset[i][1] for i in vis_indices])
        
        # Test both autoencoders
        encoding_dims = [16, 32]  # Different bottleneck sizes to test
        
        # Define different layer layouts to test
        layer_layouts = [
            ([128, 64, 32], [32, 64, 128]),  # original
            ([256, 128, 64], [64, 128, 256]),
            ([128, 64], [64, 128]),
            ([512, 128, 32], [32, 128, 512]),
            ([128], [128]),
        ]
        layout_names = [
            '[128, 64, 32]',
            '[256, 128, 64]',
            '[128, 64]',
            '[512, 128, 32]',
            '[128]'
        ]
        
        for layout, layout_name in zip(layer_layouts, layout_names):
            encoder_layers, decoder_layers = layout
            print(f"\nTesting with layer layout: encoder={encoder_layers}, decoder={decoder_layers}")
            all_train_losses = []
            all_val_losses = []
            all_reconstructions = []
            for dim in encoding_dims:
                print(f"\n  Encoding dimension: {dim}")
                # Masked Autoencoder
                masked_ae = Autoencoder(
                    encoding_dim=dim,
                    encoder_layers=encoder_layers,
                    decoder_layers=decoder_layers,
                    input_dim=param_data.shape[1]
                ).to(device)
                train_losses, val_losses = train_autoencoder(
                    masked_ae, train_loader, val_loader, 
                    num_epochs=20, device=device, 
                    model_name=f'masked_ae_{parameter_name}_dim{dim}_layout{layout_name}'
                )
                all_train_losses.append(train_losses)
                all_val_losses.append(val_losses)
                masked_ae.eval()
                with torch.no_grad():
                    vis_data = vis_data.to(device)
                    vis_mask = vis_mask.to(device)
                    masked_recon = masked_ae(vis_data, vis_mask)
                all_reconstructions.append(masked_recon)
                captured_var = calculate_captured_variance(vis_data, masked_recon, vis_mask)
                print(f"    Captured variance: {captured_var:.2f}%")
            # Plot combined results for this layout
            plot_combined_losses(all_train_losses, all_val_losses, f"{parameter_name} (layout {layout_name})", encoding_dims)
            plot_combined_profiles(vis_data, all_reconstructions, vis_mask, f"{parameter_name} (layout {layout_name})", encoding_dims, num_vis_profiles)

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Available parameters: ['temperature_TEMP', 'salinity_PSAL']
#
# Processing parameters: ['salinity_PSAL', 'temperature_TEMP']
#
# ==================================================
# Processing parameter: salinity_PSAL
# ==================================================
#
# Testing with layer layout: encoder=[128, 64, 32], decoder=[32, 64, 128]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:01<00:00, 107.89it/s]
# Training Loss: 5.44e-01 | Validation Loss: 3.07e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 227.85it/s]
# Training Loss: 2.42e-01 | Validation Loss: 2.35e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 233.46it/s]
# Training Loss: 1.95e-01 | Validation Loss: 1.72e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 233.48it/s]
# Training Loss: 1.40e-01 | Validation Loss: 1.31e-01
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 233.66it/s]
# Training Loss: 1.10e-01 | Validation Loss: 1.08e-01
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 222.42it/s]
# Training Loss: 9.38e-02 | Validation Loss: 8.79e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 223.39it/s]
# Training Loss: 7.98e-02 | Validation Loss: 7.40e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 233.92it/s]
# Training Loss: 6.85e-02 | Validation Loss: 6.83e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 230.30it/s]
# Training Loss: 6.59e-02 | Validation Loss: 6.26e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 234.63it/s]
# Training Loss: 6.24e-02 | Validation Loss: 5.88e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 230.51it/s]
# Training Loss: 5.78e-02 | Validation Loss: 5.78e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 246.97it/s]
# Training Loss: 5.46e-02 | Validation Loss: 5.44e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 242.54it/s]
# Training Loss: 5.17e-02 | Validation Loss: 5.23e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 246.38it/s]
# Training Loss: 5.09e-02 | Validation Loss: 5.01e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 245.84it/s]
# Training Loss: 5.05e-02 | Validation Loss: 5.03e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 246.95it/s]
# Training Loss: 4.77e-02 | Validation Loss: 4.79e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 246.83it/s]
# Training Loss: 4.52e-02 | Validation Loss: 5.05e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 245.77it/s]
# Training Loss: 4.68e-02 | Validation Loss: 4.32e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 245.34it/s]
# Training Loss: 4.18e-02 | Validation Loss: 4.20e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 247.29it/s]
# Training Loss: 4.08e-02 | Validation Loss: 4.33e-02
#     Captured variance: 94.36%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 244.04it/s]
# Training Loss: 6.09e-01 | Validation Loss: 3.47e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 240.87it/s]
# Training Loss: 2.53e-01 | Validation Loss: 2.14e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 247.58it/s]
# Training Loss: 1.67e-01 | Validation Loss: 1.48e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 248.15it/s]
# Training Loss: 1.31e-01 | Validation Loss: 1.20e-01
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 248.49it/s]
# Training Loss: 1.08e-01 | Validation Loss: 1.18e-01
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 256.34it/s]
# Training Loss: 9.59e-02 | Validation Loss: 8.96e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 246.43it/s]
# Training Loss: 8.37e-02 | Validation Loss: 9.21e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 243.66it/s]
# Training Loss: 8.09e-02 | Validation Loss: 7.45e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 254.41it/s]
# Training Loss: 6.87e-02 | Validation Loss: 6.59e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 247.55it/s]
# Training Loss: 6.31e-02 | Validation Loss: 5.97e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 254.48it/s]
# Training Loss: 5.99e-02 | Validation Loss: 5.80e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 244.76it/s]
# Training Loss: 5.57e-02 | Validation Loss: 5.62e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 253.87it/s]
# Training Loss: 5.41e-02 | Validation Loss: 5.43e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 256.00it/s]
# Training Loss: 5.13e-02 | Validation Loss: 5.22e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 249.14it/s]
# Training Loss: 5.18e-02 | Validation Loss: 5.00e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 257.91it/s]
# Training Loss: 4.89e-02 | Validation Loss: 5.46e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 245.91it/s]
# Training Loss: 4.84e-02 | Validation Loss: 4.88e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 253.61it/s]
# Training Loss: 4.57e-02 | Validation Loss: 4.82e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 256.23it/s]
# Training Loss: 4.48e-02 | Validation Loss: 4.70e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 248.55it/s]
# Training Loss: 4.33e-02 | Validation Loss: 4.34e-02
#     Captured variance: 93.94%
# Testing with layer layout: encoder=[256, 128, 64], decoder=[64, 128, 256]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 324.32it/s]
# Training Loss: 4.52e-01 | Validation Loss: 3.02e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 246.67it/s]
# Training Loss: 2.24e-01 | Validation Loss: 1.82e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 253.72it/s]
# Training Loss: 1.40e-01 | Validation Loss: 1.21e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 244.00it/s]
# Training Loss: 1.05e-01 | Validation Loss: 9.31e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 243.80it/s]
# Training Loss: 7.98e-02 | Validation Loss: 7.26e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 245.90it/s]
# Training Loss: 6.86e-02 | Validation Loss: 6.60e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 245.52it/s]
# Training Loss: 5.92e-02 | Validation Loss: 5.89e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 243.70it/s]
# Training Loss: 5.48e-02 | Validation Loss: 5.50e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 239.99it/s]
# Training Loss: 5.16e-02 | Validation Loss: 5.11e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 240.87it/s]
# Training Loss: 4.93e-02 | Validation Loss: 4.88e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 243.09it/s]
# Training Loss: 4.68e-02 | Validation Loss: 4.68e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 237.38it/s]
# Training Loss: 4.34e-02 | Validation Loss: 4.65e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 233.69it/s]
# Training Loss: 4.09e-02 | Validation Loss: 4.11e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 234.84it/s]
# Training Loss: 4.24e-02 | Validation Loss: 4.33e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 236.66it/s]
# Training Loss: 3.94e-02 | Validation Loss: 4.05e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 237.58it/s]
# Training Loss: 3.70e-02 | Validation Loss: 4.01e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 257.37it/s]
# Training Loss: 3.49e-02 | Validation Loss: 3.60e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 241.80it/s]
# Training Loss: 3.41e-02 | Validation Loss: 3.85e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 240.30it/s]
# Training Loss: 3.53e-02 | Validation Loss: 3.85e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 239.54it/s]
# Training Loss: 3.51e-02 | Validation Loss: 3.84e-02
#     Captured variance: 95.37%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 240.38it/s]
# Training Loss: 4.50e-01 | Validation Loss: 2.85e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 260.67it/s]
# Training Loss: 2.46e-01 | Validation Loss: 2.25e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 240.81it/s]
# Training Loss: 1.91e-01 | Validation Loss: 1.39e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 244.29it/s]
# Training Loss: 1.16e-01 | Validation Loss: 1.12e-01
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 244.98it/s]
# Training Loss: 9.07e-02 | Validation Loss: 8.32e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 243.74it/s]
# Training Loss: 7.45e-02 | Validation Loss: 6.79e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 243.43it/s]
# Training Loss: 6.49e-02 | Validation Loss: 5.94e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 245.92it/s]
# Training Loss: 5.76e-02 | Validation Loss: 6.00e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 242.71it/s]
# Training Loss: 5.54e-02 | Validation Loss: 5.64e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 243.73it/s]
# Training Loss: 5.40e-02 | Validation Loss: 5.73e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 251.72it/s]
# Training Loss: 5.55e-02 | Validation Loss: 5.05e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 280.85it/s]
# Training Loss: 4.99e-02 | Validation Loss: 4.84e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 273.34it/s]
# Training Loss: 4.77e-02 | Validation Loss: 5.20e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 268.35it/s]
# Training Loss: 4.81e-02 | Validation Loss: 5.16e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 264.13it/s]
# Training Loss: 4.66e-02 | Validation Loss: 4.80e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 272.20it/s]
# Training Loss: 4.48e-02 | Validation Loss: 4.27e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 271.65it/s]
# Training Loss: 4.01e-02 | Validation Loss: 4.06e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 271.61it/s]
# Training Loss: 3.90e-02 | Validation Loss: 3.96e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 271.60it/s]
# Training Loss: 3.66e-02 | Validation Loss: 3.69e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 265.74it/s]
# Training Loss: 3.48e-02 | Validation Loss: 3.78e-02
#     Captured variance: 95.51%
# Testing with layer layout: encoder=[128, 64], decoder=[64, 128]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 290.47it/s]
# Training Loss: 4.33e-01 | Validation Loss: 2.19e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 269.35it/s]
# Training Loss: 1.50e-01 | Validation Loss: 1.12e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 266.61it/s]
# Training Loss: 8.71e-02 | Validation Loss: 7.51e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 276.53it/s]
# Training Loss: 6.50e-02 | Validation Loss: 5.83e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 281.68it/s]
# Training Loss: 5.27e-02 | Validation Loss: 4.85e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 283.82it/s]
# Training Loss: 4.70e-02 | Validation Loss: 4.71e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 280.47it/s]
# Training Loss: 4.40e-02 | Validation Loss: 4.24e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 280.04it/s]
# Training Loss: 4.00e-02 | Validation Loss: 4.12e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 282.01it/s]
# Training Loss: 3.92e-02 | Validation Loss: 3.92e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 280.61it/s]
# Training Loss: 3.57e-02 | Validation Loss: 3.60e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 276.46it/s]
# Training Loss: 3.43e-02 | Validation Loss: 3.87e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 272.90it/s]
# Training Loss: 3.40e-02 | Validation Loss: 3.43e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 276.73it/s]
# Training Loss: 3.19e-02 | Validation Loss: 3.19e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 274.18it/s]
# Training Loss: 3.03e-02 | Validation Loss: 3.18e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 279.55it/s]
# Training Loss: 2.90e-02 | Validation Loss: 3.02e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 276.02it/s]
# Training Loss: 2.86e-02 | Validation Loss: 2.95e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 279.64it/s]
# Training Loss: 2.73e-02 | Validation Loss: 3.04e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 275.18it/s]
# Training Loss: 2.72e-02 | Validation Loss: 2.77e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 276.54it/s]
# Training Loss: 2.65e-02 | Validation Loss: 2.74e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 383.57it/s]
# Training Loss: 2.45e-02 | Validation Loss: 2.56e-02
#     Captured variance: 96.09%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 315.77it/s]
# Training Loss: 4.39e-01 | Validation Loss: 2.04e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 284.51it/s]
# Training Loss: 1.34e-01 | Validation Loss: 1.05e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 286.67it/s]
# Training Loss: 8.70e-02 | Validation Loss: 7.69e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 281.36it/s]
# Training Loss: 6.96e-02 | Validation Loss: 6.66e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 283.12it/s]
# Training Loss: 5.81e-02 | Validation Loss: 5.95e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 279.37it/s]
# Training Loss: 4.92e-02 | Validation Loss: 4.70e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 281.89it/s]
# Training Loss: 4.28e-02 | Validation Loss: 4.32e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 274.97it/s]
# Training Loss: 3.91e-02 | Validation Loss: 4.20e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 298.39it/s]
# Training Loss: 3.57e-02 | Validation Loss: 3.47e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 281.70it/s]
# Training Loss: 3.30e-02 | Validation Loss: 3.35e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 309.17it/s]
# Training Loss: 3.14e-02 | Validation Loss: 3.23e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 276.51it/s]
# Training Loss: 3.01e-02 | Validation Loss: 3.33e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 276.18it/s]
# Training Loss: 2.90e-02 | Validation Loss: 3.02e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 304.94it/s]
# Training Loss: 2.70e-02 | Validation Loss: 2.74e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 280.83it/s]
# Training Loss: 2.57e-02 | Validation Loss: 2.55e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 281.15it/s]
# Training Loss: 2.48e-02 | Validation Loss: 2.86e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 276.90it/s]
# Training Loss: 2.50e-02 | Validation Loss: 2.39e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 279.59it/s]
# Training Loss: 2.33e-02 | Validation Loss: 2.46e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 278.33it/s]
# Training Loss: 2.25e-02 | Validation Loss: 2.45e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 278.45it/s]
# Training Loss: 2.26e-02 | Validation Loss: 3.14e-02
#     Captured variance: 95.85%
# Testing with layer layout: encoder=[512, 128, 32], decoder=[32, 128, 512]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 411.21it/s]
# Training Loss: 4.14e-01 | Validation Loss: 2.06e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 276.95it/s]
# Training Loss: 1.56e-01 | Validation Loss: 1.25e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 237.18it/s]
# Training Loss: 9.99e-02 | Validation Loss: 9.36e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 237.17it/s]
# Training Loss: 8.12e-02 | Validation Loss: 7.08e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 238.93it/s]
# Training Loss: 6.56e-02 | Validation Loss: 6.32e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 234.59it/s]
# Training Loss: 5.67e-02 | Validation Loss: 5.99e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 229.97it/s]
# Training Loss: 5.41e-02 | Validation Loss: 5.75e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 264.99it/s]
# Training Loss: 4.96e-02 | Validation Loss: 6.19e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 300.98it/s]
# Training Loss: 4.89e-02 | Validation Loss: 4.79e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 228.46it/s]
# Training Loss: 4.50e-02 | Validation Loss: 4.81e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 233.07it/s]
# Training Loss: 4.26e-02 | Validation Loss: 4.35e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 256.00it/s]
# Training Loss: 4.14e-02 | Validation Loss: 4.44e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 233.44it/s]
# Training Loss: 4.62e-02 | Validation Loss: 4.06e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 229.16it/s]
# Training Loss: 3.59e-02 | Validation Loss: 3.72e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 230.80it/s]
# Training Loss: 3.40e-02 | Validation Loss: 3.69e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 229.91it/s]
# Training Loss: 3.30e-02 | Validation Loss: 3.59e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 234.83it/s]
# Training Loss: 3.21e-02 | Validation Loss: 3.46e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 226.50it/s]
# Training Loss: 3.21e-02 | Validation Loss: 3.91e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 225.33it/s]
# Training Loss: 3.26e-02 | Validation Loss: 4.45e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 223.93it/s]
# Training Loss: 3.28e-02 | Validation Loss: 3.38e-02
#     Captured variance: 95.69%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 227.36it/s]
# Training Loss: 4.35e-01 | Validation Loss: 2.48e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 230.62it/s]
# Training Loss: 1.63e-01 | Validation Loss: 1.22e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 226.77it/s]
# Training Loss: 1.07e-01 | Validation Loss: 9.34e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 226.92it/s]
# Training Loss: 7.94e-02 | Validation Loss: 7.41e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 227.72it/s]
# Training Loss: 6.39e-02 | Validation Loss: 5.97e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 227.64it/s]
# Training Loss: 5.91e-02 | Validation Loss: 6.02e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 225.05it/s]
# Training Loss: 5.29e-02 | Validation Loss: 5.41e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 224.93it/s]
# Training Loss: 4.91e-02 | Validation Loss: 4.74e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 226.51it/s]
# Training Loss: 4.64e-02 | Validation Loss: 4.60e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 228.14it/s]
# Training Loss: 4.35e-02 | Validation Loss: 4.50e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 227.24it/s]
# Training Loss: 4.16e-02 | Validation Loss: 4.72e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 225.90it/s]
# Training Loss: 4.19e-02 | Validation Loss: 4.69e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 225.30it/s]
# Training Loss: 3.89e-02 | Validation Loss: 4.07e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 226.71it/s]
# Training Loss: 4.13e-02 | Validation Loss: 5.06e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 226.63it/s]
# Training Loss: 3.80e-02 | Validation Loss: 3.73e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 229.09it/s]
# Training Loss: 3.50e-02 | Validation Loss: 3.87e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 228.48it/s]
# Training Loss: 3.57e-02 | Validation Loss: 3.59e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 231.04it/s]
# Training Loss: 3.36e-02 | Validation Loss: 4.12e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 229.51it/s]
# Training Loss: 3.31e-02 | Validation Loss: 3.91e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 231.18it/s]
# Training Loss: 3.53e-02 | Validation Loss: 3.72e-02
#     Captured variance: 94.83%
# Testing with layer layout: encoder=[128], decoder=[128]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 373.38it/s]
# Training Loss: 3.18e-01 | Validation Loss: 9.47e-02
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 322.31it/s]
# Training Loss: 6.77e-02 | Validation Loss: 5.40e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 318.21it/s]
# Training Loss: 4.48e-02 | Validation Loss: 3.90e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 335.39it/s]
# Training Loss: 3.61e-02 | Validation Loss: 3.34e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 339.19it/s]
# Training Loss: 3.18e-02 | Validation Loss: 3.07e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 323.01it/s]
# Training Loss: 2.92e-02 | Validation Loss: 2.83e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 323.20it/s]
# Training Loss: 2.66e-02 | Validation Loss: 2.63e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 316.32it/s]
# Training Loss: 2.47e-02 | Validation Loss: 2.83e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 314.37it/s]
# Training Loss: 2.35e-02 | Validation Loss: 2.29e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 323.40it/s]
# Training Loss: 2.10e-02 | Validation Loss: 2.15e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 315.78it/s]
# Training Loss: 2.02e-02 | Validation Loss: 2.09e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 333.10it/s]
# Training Loss: 1.97e-02 | Validation Loss: 2.12e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 411.97it/s]
# Training Loss: 1.91e-02 | Validation Loss: 2.10e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 331.31it/s]
# Training Loss: 1.89e-02 | Validation Loss: 1.96e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 332.89it/s]
# Training Loss: 1.80e-02 | Validation Loss: 1.90e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 331.23it/s]
# Training Loss: 1.78e-02 | Validation Loss: 1.82e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 330.00it/s]
# Training Loss: 1.65e-02 | Validation Loss: 1.82e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 331.35it/s]
# Training Loss: 1.65e-02 | Validation Loss: 1.80e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 333.85it/s]
# Training Loss: 1.61e-02 | Validation Loss: 1.72e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 336.19it/s]
# Training Loss: 1.58e-02 | Validation Loss: 1.61e-02
#     Captured variance: 97.81%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 334.96it/s]
# Training Loss: 3.17e-01 | Validation Loss: 9.50e-02
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 325.71it/s]
# Training Loss: 6.69e-02 | Validation Loss: 5.18e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 565.05it/s]
# Training Loss: 4.28e-02 | Validation Loss: 3.88e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 640.99it/s]
# Training Loss: 3.43e-02 | Validation Loss: 3.31e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 655.65it/s]
# Training Loss: 3.01e-02 | Validation Loss: 2.89e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 648.97it/s]
# Training Loss: 2.71e-02 | Validation Loss: 2.54e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 655.35it/s]
# Training Loss: 2.38e-02 | Validation Loss: 2.32e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 668.75it/s]
# Training Loss: 2.24e-02 | Validation Loss: 2.47e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 652.07it/s]
# Training Loss: 2.32e-02 | Validation Loss: 2.23e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 377.87it/s]
# Training Loss: 2.04e-02 | Validation Loss: 1.91e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 339.68it/s]
# Training Loss: 1.90e-02 | Validation Loss: 1.93e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 330.27it/s]
# Training Loss: 1.82e-02 | Validation Loss: 1.94e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 334.35it/s]
# Training Loss: 1.79e-02 | Validation Loss: 1.83e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 331.30it/s]
# Training Loss: 1.63e-02 | Validation Loss: 1.70e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 330.77it/s]
# Training Loss: 1.59e-02 | Validation Loss: 1.79e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 334.34it/s]
# Training Loss: 1.49e-02 | Validation Loss: 1.53e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 332.63it/s]
# Training Loss: 1.47e-02 | Validation Loss: 1.42e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 334.15it/s]
# Training Loss: 1.37e-02 | Validation Loss: 1.60e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 332.02it/s]
# Training Loss: 1.46e-02 | Validation Loss: 1.42e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 332.48it/s]
# Training Loss: 1.32e-02 | Validation Loss: 1.45e-02
#     Captured variance: 98.41%
# ==================================================
# Processing parameter: temperature_TEMP
# ==================================================
#
# Testing with layer layout: encoder=[128, 64, 32], decoder=[32, 64, 128]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 389.70it/s]
# Training Loss: 4.38e-01 | Validation Loss: 2.65e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 466.49it/s]
# Training Loss: 2.58e-01 | Validation Loss: 2.18e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 470.01it/s]
# Training Loss: 1.52e-01 | Validation Loss: 1.00e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 409.76it/s]
# Training Loss: 9.26e-02 | Validation Loss: 9.61e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 281.00it/s]
# Training Loss: 8.71e-02 | Validation Loss: 8.77e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 247.54it/s]
# Training Loss: 7.84e-02 | Validation Loss: 7.46e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 243.74it/s]
# Training Loss: 6.47e-02 | Validation Loss: 5.98e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 241.13it/s]
# Training Loss: 5.28e-02 | Validation Loss: 5.11e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 243.57it/s]
# Training Loss: 4.77e-02 | Validation Loss: 5.34e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 240.57it/s]
# Training Loss: 4.43e-02 | Validation Loss: 4.40e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 248.15it/s]
# Training Loss: 4.04e-02 | Validation Loss: 4.26e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 249.65it/s]
# Training Loss: 3.83e-02 | Validation Loss: 3.95e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 240.26it/s]
# Training Loss: 3.66e-02 | Validation Loss: 3.87e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 234.23it/s]
# Training Loss: 3.55e-02 | Validation Loss: 3.73e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 238.70it/s]
# Training Loss: 3.42e-02 | Validation Loss: 3.40e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 239.06it/s]
# Training Loss: 2.94e-02 | Validation Loss: 2.97e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 292.17it/s]
# Training Loss: 2.75e-02 | Validation Loss: 2.67e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 245.91it/s]
# Training Loss: 2.42e-02 | Validation Loss: 2.74e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 227.43it/s]
# Training Loss: 2.35e-02 | Validation Loss: 2.56e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 227.92it/s]
# Training Loss: 2.33e-02 | Validation Loss: 2.51e-02
#     Captured variance: 97.88%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 229.28it/s]
# Training Loss: 4.36e-01 | Validation Loss: 2.65e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 228.72it/s]
# Training Loss: 2.29e-01 | Validation Loss: 1.65e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 231.91it/s]
# Training Loss: 1.45e-01 | Validation Loss: 1.34e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 229.39it/s]
# Training Loss: 1.12e-01 | Validation Loss: 9.39e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 229.56it/s]
# Training Loss: 8.85e-02 | Validation Loss: 8.46e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 243.98it/s]
# Training Loss: 7.87e-02 | Validation Loss: 7.46e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 287.66it/s]
# Training Loss: 6.10e-02 | Validation Loss: 5.64e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 243.71it/s]
# Training Loss: 4.99e-02 | Validation Loss: 4.94e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 228.78it/s]
# Training Loss: 4.52e-02 | Validation Loss: 4.95e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 228.04it/s]
# Training Loss: 3.87e-02 | Validation Loss: 3.83e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 231.38it/s]
# Training Loss: 3.47e-02 | Validation Loss: 3.43e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 230.70it/s]
# Training Loss: 3.23e-02 | Validation Loss: 3.49e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 228.10it/s]
# Training Loss: 3.04e-02 | Validation Loss: 3.25e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 234.17it/s]
# Training Loss: 2.80e-02 | Validation Loss: 2.95e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 229.27it/s]
# Training Loss: 2.72e-02 | Validation Loss: 3.11e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 227.14it/s]
# Training Loss: 2.66e-02 | Validation Loss: 2.81e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 231.44it/s]
# Training Loss: 2.59e-02 | Validation Loss: 2.70e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 231.97it/s]
# Training Loss: 2.54e-02 | Validation Loss: 2.73e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 228.90it/s]
# Training Loss: 2.42e-02 | Validation Loss: 2.63e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 254.06it/s]
# Training Loss: 2.41e-02 | Validation Loss: 2.96e-02
#     Captured variance: 96.99%
# Testing with layer layout: encoder=[256, 128, 64], decoder=[64, 128, 256]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 342.87it/s]
# Training Loss: 3.57e-01 | Validation Loss: 1.99e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 229.08it/s]
# Training Loss: 1.20e-01 | Validation Loss: 1.06e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 231.76it/s]
# Training Loss: 9.03e-02 | Validation Loss: 9.34e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 234.02it/s]
# Training Loss: 8.45e-02 | Validation Loss: 9.24e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 232.48it/s]
# Training Loss: 7.35e-02 | Validation Loss: 6.53e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 228.59it/s]
# Training Loss: 5.69e-02 | Validation Loss: 5.90e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 225.83it/s]
# Training Loss: 4.90e-02 | Validation Loss: 5.35e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 227.33it/s]
# Training Loss: 4.22e-02 | Validation Loss: 4.54e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 227.60it/s]
# Training Loss: 3.72e-02 | Validation Loss: 3.80e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 229.63it/s]
# Training Loss: 3.20e-02 | Validation Loss: 3.45e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 228.31it/s]
# Training Loss: 3.02e-02 | Validation Loss: 3.29e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 228.46it/s]
# Training Loss: 2.83e-02 | Validation Loss: 2.93e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 237.30it/s]
# Training Loss: 2.62e-02 | Validation Loss: 2.85e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 243.48it/s]
# Training Loss: 2.58e-02 | Validation Loss: 2.85e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 241.38it/s]
# Training Loss: 2.52e-02 | Validation Loss: 2.66e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 242.70it/s]
# Training Loss: 2.38e-02 | Validation Loss: 2.78e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 240.64it/s]
# Training Loss: 2.43e-02 | Validation Loss: 2.71e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 239.60it/s]
# Training Loss: 2.42e-02 | Validation Loss: 2.63e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 242.21it/s]
# Training Loss: 2.38e-02 | Validation Loss: 2.79e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 238.07it/s]
# Training Loss: 2.29e-02 | Validation Loss: 2.73e-02
#     Captured variance: 97.64%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 240.26it/s]
# Training Loss: 3.73e-01 | Validation Loss: 2.68e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 253.92it/s]
# Training Loss: 1.87e-01 | Validation Loss: 1.20e-01
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 253.04it/s]
# Training Loss: 9.57e-02 | Validation Loss: 1.03e-01
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 241.32it/s]
# Training Loss: 8.72e-02 | Validation Loss: 8.07e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 249.27it/s]
# Training Loss: 7.13e-02 | Validation Loss: 6.49e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 245.49it/s]
# Training Loss: 5.81e-02 | Validation Loss: 5.90e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 243.89it/s]
# Training Loss: 5.04e-02 | Validation Loss: 4.78e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 241.96it/s]
# Training Loss: 4.16e-02 | Validation Loss: 4.55e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 243.78it/s]
# Training Loss: 3.72e-02 | Validation Loss: 4.00e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 244.95it/s]
# Training Loss: 3.50e-02 | Validation Loss: 3.87e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 242.58it/s]
# Training Loss: 3.29e-02 | Validation Loss: 3.65e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 245.84it/s]
# Training Loss: 3.02e-02 | Validation Loss: 3.10e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 251.77it/s]
# Training Loss: 2.69e-02 | Validation Loss: 2.82e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 244.32it/s]
# Training Loss: 2.56e-02 | Validation Loss: 2.66e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 243.55it/s]
# Training Loss: 2.42e-02 | Validation Loss: 2.87e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 241.41it/s]
# Training Loss: 2.59e-02 | Validation Loss: 3.26e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 241.93it/s]
# Training Loss: 2.43e-02 | Validation Loss: 2.59e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 243.01it/s]
# Training Loss: 2.38e-02 | Validation Loss: 2.60e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 241.95it/s]
# Training Loss: 2.22e-02 | Validation Loss: 2.71e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 241.40it/s]
# Training Loss: 2.22e-02 | Validation Loss: 2.63e-02
#     Captured variance: 97.69%
# Testing with layer layout: encoder=[128, 64], decoder=[64, 128]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 519.14it/s]
# Training Loss: 3.20e-01 | Validation Loss: 1.08e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 305.30it/s]
# Training Loss: 9.70e-02 | Validation Loss: 9.05e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 282.08it/s]
# Training Loss: 6.79e-02 | Validation Loss: 5.81e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 283.10it/s]
# Training Loss: 4.16e-02 | Validation Loss: 3.76e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 283.40it/s]
# Training Loss: 3.12e-02 | Validation Loss: 2.98e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 282.55it/s]
# Training Loss: 2.58e-02 | Validation Loss: 2.95e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 291.35it/s]
# Training Loss: 2.43e-02 | Validation Loss: 2.60e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 284.80it/s]
# Training Loss: 2.36e-02 | Validation Loss: 2.55e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 279.40it/s]
# Training Loss: 2.23e-02 | Validation Loss: 2.59e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 275.85it/s]
# Training Loss: 2.21e-02 | Validation Loss: 2.37e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 280.04it/s]
# Training Loss: 2.11e-02 | Validation Loss: 2.34e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 281.77it/s]
# Training Loss: 2.10e-02 | Validation Loss: 2.43e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 279.55it/s]
# Training Loss: 2.03e-02 | Validation Loss: 2.08e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 280.73it/s]
# Training Loss: 1.92e-02 | Validation Loss: 2.12e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 278.46it/s]
# Training Loss: 1.86e-02 | Validation Loss: 1.97e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 283.58it/s]
# Training Loss: 1.78e-02 | Validation Loss: 2.12e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 279.67it/s]
# Training Loss: 1.74e-02 | Validation Loss: 2.25e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 277.63it/s]
# Training Loss: 1.68e-02 | Validation Loss: 1.76e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 281.60it/s]
# Training Loss: 1.57e-02 | Validation Loss: 1.79e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 279.87it/s]
# Training Loss: 1.53e-02 | Validation Loss: 1.87e-02
#     Captured variance: 98.50%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 278.03it/s]
# Training Loss: 3.22e-01 | Validation Loss: 1.08e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 282.13it/s]
# Training Loss: 9.62e-02 | Validation Loss: 8.89e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 283.04it/s]
# Training Loss: 7.07e-02 | Validation Loss: 6.49e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 283.62it/s]
# Training Loss: 4.93e-02 | Validation Loss: 4.54e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 280.74it/s]
# Training Loss: 3.91e-02 | Validation Loss: 3.80e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 285.29it/s]
# Training Loss: 3.21e-02 | Validation Loss: 3.35e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 349.93it/s]
# Training Loss: 2.73e-02 | Validation Loss: 2.77e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 362.85it/s]
# Training Loss: 2.50e-02 | Validation Loss: 3.35e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 285.74it/s]
# Training Loss: 2.46e-02 | Validation Loss: 2.43e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 287.68it/s]
# Training Loss: 2.22e-02 | Validation Loss: 2.32e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 283.74it/s]
# Training Loss: 2.14e-02 | Validation Loss: 2.34e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 287.45it/s]
# Training Loss: 2.05e-02 | Validation Loss: 2.26e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 292.00it/s]
# Training Loss: 2.00e-02 | Validation Loss: 2.17e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 286.66it/s]
# Training Loss: 1.90e-02 | Validation Loss: 2.23e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 280.00it/s]
# Training Loss: 1.82e-02 | Validation Loss: 2.04e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 283.48it/s]
# Training Loss: 1.73e-02 | Validation Loss: 1.86e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 284.47it/s]
# Training Loss: 1.69e-02 | Validation Loss: 2.11e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 281.79it/s]
# Training Loss: 1.62e-02 | Validation Loss: 1.78e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 282.48it/s]
# Training Loss: 1.57e-02 | Validation Loss: 1.76e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 283.18it/s]
# Training Loss: 1.54e-02 | Validation Loss: 1.71e-02
#     Captured variance: 99.10%
# Testing with layer layout: encoder=[512, 128, 32], decoder=[32, 128, 512]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 314.33it/s]
# Training Loss: 3.40e-01 | Validation Loss: 1.94e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 234.42it/s]
# Training Loss: 1.07e-01 | Validation Loss: 8.95e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 237.67it/s]
# Training Loss: 8.53e-02 | Validation Loss: 9.44e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 236.14it/s]
# Training Loss: 6.96e-02 | Validation Loss: 5.65e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 238.32it/s]
# Training Loss: 5.01e-02 | Validation Loss: 5.36e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 238.90it/s]
# Training Loss: 4.32e-02 | Validation Loss: 4.73e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 233.60it/s]
# Training Loss: 3.90e-02 | Validation Loss: 3.79e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 239.94it/s]
# Training Loss: 3.39e-02 | Validation Loss: 3.91e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 236.34it/s]
# Training Loss: 3.08e-02 | Validation Loss: 3.34e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 238.63it/s]
# Training Loss: 2.76e-02 | Validation Loss: 3.06e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 233.61it/s]
# Training Loss: 2.52e-02 | Validation Loss: 3.36e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 234.39it/s]
# Training Loss: 2.51e-02 | Validation Loss: 2.62e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 228.17it/s]
# Training Loss: 2.30e-02 | Validation Loss: 2.56e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 238.32it/s]
# Training Loss: 2.14e-02 | Validation Loss: 2.35e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 236.46it/s]
# Training Loss: 2.12e-02 | Validation Loss: 2.56e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 235.41it/s]
# Training Loss: 2.01e-02 | Validation Loss: 2.55e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 234.61it/s]
# Training Loss: 2.08e-02 | Validation Loss: 2.60e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 270.41it/s]
# Training Loss: 1.99e-02 | Validation Loss: 2.24e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 262.90it/s]
# Training Loss: 1.87e-02 | Validation Loss: 2.20e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 240.49it/s]
# Training Loss: 1.87e-02 | Validation Loss: 2.14e-02
#     Captured variance: 98.07%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 239.71it/s]
# Training Loss: 3.30e-01 | Validation Loss: 1.29e-01
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 240.81it/s]
# Training Loss: 1.02e-01 | Validation Loss: 8.81e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 237.69it/s]
# Training Loss: 8.55e-02 | Validation Loss: 8.23e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 234.07it/s]
# Training Loss: 6.74e-02 | Validation Loss: 5.84e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 236.43it/s]
# Training Loss: 4.78e-02 | Validation Loss: 5.29e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 223.34it/s]
# Training Loss: 4.19e-02 | Validation Loss: 4.25e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 218.94it/s]
# Training Loss: 3.81e-02 | Validation Loss: 4.68e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 263.10it/s]
# Training Loss: 4.01e-02 | Validation Loss: 3.89e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 233.15it/s]
# Training Loss: 3.54e-02 | Validation Loss: 4.10e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 237.78it/s]
# Training Loss: 3.35e-02 | Validation Loss: 3.27e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 235.21it/s]
# Training Loss: 2.79e-02 | Validation Loss: 3.13e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 240.17it/s]
# Training Loss: 2.72e-02 | Validation Loss: 2.92e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 293.80it/s]
# Training Loss: 2.48e-02 | Validation Loss: 2.82e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 244.73it/s]
# Training Loss: 2.44e-02 | Validation Loss: 2.69e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 236.08it/s]
# Training Loss: 2.40e-02 | Validation Loss: 2.66e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 240.63it/s]
# Training Loss: 2.30e-02 | Validation Loss: 2.58e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 236.31it/s]
# Training Loss: 2.32e-02 | Validation Loss: 3.39e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 236.56it/s]
# Training Loss: 2.30e-02 | Validation Loss: 2.53e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 236.69it/s]
# Training Loss: 2.20e-02 | Validation Loss: 2.62e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 236.74it/s]
# Training Loss: 2.19e-02 | Validation Loss: 3.20e-02
#     Captured variance: 98.23%
# Testing with layer layout: encoder=[128], decoder=[128]
#
#   Encoding dimension: 16
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 676.33it/s]
# Training Loss: 2.47e-01 | Validation Loss: 8.38e-02
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 666.65it/s]
# Training Loss: 5.44e-02 | Validation Loss: 3.96e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 652.68it/s]
# Training Loss: 2.95e-02 | Validation Loss: 2.61e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 656.32it/s]
# Training Loss: 2.30e-02 | Validation Loss: 2.32e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 648.99it/s]
# Training Loss: 2.01e-02 | Validation Loss: 1.96e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 652.36it/s]
# Training Loss: 1.78e-02 | Validation Loss: 1.81e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 647.81it/s]
# Training Loss: 1.57e-02 | Validation Loss: 1.63e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 633.47it/s]
# Training Loss: 1.48e-02 | Validation Loss: 1.62e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 645.30it/s]
# Training Loss: 1.39e-02 | Validation Loss: 1.52e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 647.14it/s]
# Training Loss: 1.35e-02 | Validation Loss: 1.50e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 659.99it/s]
# Training Loss: 1.28e-02 | Validation Loss: 1.51e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 627.85it/s]
# Training Loss: 1.25e-02 | Validation Loss: 1.41e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 648.36it/s]
# Training Loss: 1.21e-02 | Validation Loss: 1.34e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 641.53it/s]
# Training Loss: 1.14e-02 | Validation Loss: 1.28e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 647.51it/s]
# Training Loss: 1.15e-02 | Validation Loss: 1.43e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 647.29it/s]
# Training Loss: 1.19e-02 | Validation Loss: 1.24e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 648.32it/s]
# Training Loss: 1.06e-02 | Validation Loss: 1.20e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 648.65it/s]
# Training Loss: 1.04e-02 | Validation Loss: 1.12e-02
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 650.21it/s]
# Training Loss: 1.06e-02 | Validation Loss: 1.15e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 649.97it/s]
# Training Loss: 1.01e-02 | Validation Loss: 1.13e-02
#     Captured variance: 99.34%
#
#   Encoding dimension: 32
# Epoch 1/20: 100%|██████████| 127/127 [00:00<00:00, 650.43it/s]
# Training Loss: 2.47e-01 | Validation Loss: 8.35e-02
# Epoch 2/20: 100%|██████████| 127/127 [00:00<00:00, 650.76it/s]
# Training Loss: 5.10e-02 | Validation Loss: 3.64e-02
# Epoch 3/20: 100%|██████████| 127/127 [00:00<00:00, 664.48it/s]
# Training Loss: 2.85e-02 | Validation Loss: 2.65e-02
# Epoch 4/20: 100%|██████████| 127/127 [00:00<00:00, 653.54it/s]
# Training Loss: 2.22e-02 | Validation Loss: 2.17e-02
# Epoch 5/20: 100%|██████████| 127/127 [00:00<00:00, 642.56it/s]
# Training Loss: 1.88e-02 | Validation Loss: 1.98e-02
# Epoch 6/20: 100%|██████████| 127/127 [00:00<00:00, 650.10it/s]
# Training Loss: 1.68e-02 | Validation Loss: 1.91e-02
# Epoch 7/20: 100%|██████████| 127/127 [00:00<00:00, 652.04it/s]
# Training Loss: 1.55e-02 | Validation Loss: 1.62e-02
# Epoch 8/20: 100%|██████████| 127/127 [00:00<00:00, 654.99it/s]
# Training Loss: 1.45e-02 | Validation Loss: 1.50e-02
# Epoch 9/20: 100%|██████████| 127/127 [00:00<00:00, 638.88it/s]
# Training Loss: 1.35e-02 | Validation Loss: 1.42e-02
# Epoch 10/20: 100%|██████████| 127/127 [00:00<00:00, 654.52it/s]
# Training Loss: 1.28e-02 | Validation Loss: 1.36e-02
# Epoch 11/20: 100%|██████████| 127/127 [00:00<00:00, 655.06it/s]
# Training Loss: 1.16e-02 | Validation Loss: 1.39e-02
# Epoch 12/20: 100%|██████████| 127/127 [00:00<00:00, 653.76it/s]
# Training Loss: 1.12e-02 | Validation Loss: 1.22e-02
# Epoch 13/20: 100%|██████████| 127/127 [00:00<00:00, 645.15it/s]
# Training Loss: 1.05e-02 | Validation Loss: 1.15e-02
# Epoch 14/20: 100%|██████████| 127/127 [00:00<00:00, 652.64it/s]
# Training Loss: 1.04e-02 | Validation Loss: 1.17e-02
# Epoch 15/20: 100%|██████████| 127/127 [00:00<00:00, 651.42it/s]
# Training Loss: 9.78e-03 | Validation Loss: 1.06e-02
# Epoch 16/20: 100%|██████████| 127/127 [00:00<00:00, 653.56it/s]
# Training Loss: 9.66e-03 | Validation Loss: 1.04e-02
# Epoch 17/20: 100%|██████████| 127/127 [00:00<00:00, 649.88it/s]
# Training Loss: 9.45e-03 | Validation Loss: 1.10e-02
# Epoch 18/20: 100%|██████████| 127/127 [00:00<00:00, 652.52it/s]
# Training Loss: 9.13e-03 | Validation Loss: 9.87e-03
# Epoch 19/20: 100%|██████████| 127/127 [00:00<00:00, 350.76it/s]
# Training Loss: 8.97e-03 | Validation Loss: 1.07e-02
# Epoch 20/20: 100%|██████████| 127/127 [00:00<00:00, 330.36it/s]
# Training Loss: 8.85e-03 | Validation Loss: 9.73e-03
#     Captured variance: 99.48%
